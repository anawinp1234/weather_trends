# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
file = '/Users/anawinp/Projects/weather_trends/data/weather_dataset_19-01-2020.csv'
df = pd.read_csv(file, index_col = 0)
df.head(10)
# Out:
#                 current_time                crawled_at     pressure  \
# index
# 0      19 Jan 2020, 11:06:34  Sun Jan 19 15:36:34 2020    1020 mbar
# 1      19 Jan 2020, 20:36:34  Sun Jan 19 15:36:34 2020    1008 mbar
# 2      19 Jan 2020, 21:06:34  Sun Jan 19 15:36:34 2020    1006 mbar
# 3      19 Jan 2020, 11:06:34  Sun Jan 19 15:36:34 2020    1012 mbar
# 4      19 Jan 2020, 11:06:34  Sun Jan 19 15:36:35 2020          N/A
# 5      19 Jan 2020, 11:06:34  Sun Jan 19 15:36:35 2020   1031 mbar
# 6      19 Jan 2020, 11:06:34  Sun Jan 19 15:36:35 2020    1021 mbar
# 7      19 Jan 2020, 21:06:35  Sun Jan 19 15:36:35 2020          N/A
# 8      19 Jan 2020, 11:06:35  Sun Jan 19 15:36:35 2020   1036 mbar
# 9      19 Jan 2020, 11:06:35  Sun Jan 19 15:36:35 2020    1031 mbar
#
#          country   wind_direction                sky  \
# index
# 0        Albania   from Southeast     Broken clouds.
# 1      Australia       from South              Cool.
# 2      Australia               na              Mild.
# 3         Angola   from Southwest  Scattered clouds.
# 4        Austria   from Southwest          Overcast.
# 5        Austria   from Northwest            Chilly.
# 6        Albania       from South  Scattered clouds.
# 7      Australia       from South              Mild.
# 8        Austria   from Southeast            Chilly.
# 9        Austria   from Northwest            Chilly.
#
#                                     uniq_id visibility temparature dev_point  \
# index
# 0      6817a79c-0213-5c79-bb75-88bc16ca44dd        N/A       11 °C      8 °C
# 1      215d740f-ed79-5643-80a3-5fdcbc7b6b54        N/A       16 °C     15 °C
# 2      fe46e09e-8735-54bd-9e86-19ae8335e915        N/A       22 °C     19 °C
# 3      6aa0c99b-30b6-5e10-bddc-523b24ca8f63        N/A       30 °C     25 °C
# 4      6fc9e671-d5ad-563f-8c03-ade510d95ef0      12 km       -2 °C     -5 °C
# 5      902c57ff-f415-5a3a-9566-7979c4a9b8f9        N/A        2 °C      1 °C
# 6      31612738-627f-5dbb-a7e7-b2bc4e86fdd8        N/A       12 °C      6 °C
# 7      cfd2a7f9-1d46-5520-ab7f-8eec7fe2a3b5        N/A       22 °C     19 °C
# 8      eb0c5057-19df-5b83-9850-e7bf3760d2bc        N/A       -4 °C     -7 °C
# 9      cc5457af-5518-5bc9-bbdc-2b7a4049263c        N/A        2 °C      1 °C
#
#                                                    place  \
# index
# 0                        Weather in Gjirokastër, Albania
# 1       Weather in Mount Gambier, South Australia, Au...
# 2            Weather in Eden, New South Wales, Australia
# 3                             Weather in Cabinda, Angola
# 4                   Weather in Mayrhofen, Tyrol, Austria
# 5              Weather in Zwettl, Lower Austria, Austria
# 6                             Weather in Tirana, Albania
# 7       Weather in Wollongong, New South Wales, Austr...
# 8                      Weather in Reutte, Tyrol, Austria
# 9          Weather in Hollabrunn, Lower Austria, Austria
#
#                       location data_category        latest_report      wind  \
# index
# 0              Kerkyra Airport       weather   19 Jan 2020, 10:20  11 km/h
# 1      Mount Gambier Aerodrome       weather   19 Jan 2020, 19:30  30 km/h
# 2               Green Cape Aws       weather   19 Jan 2020, 20:00   No wind
# 3         Pointe Airport-Noire       weather   19 Jan 2020, 10:00   7 km/h
# 4                       Krimml       weather   19 Jan 2020, 10:00   2 km/h
# 5                         Retz       weather   19 Jan 2020, 10:00   7 km/h
# 6               Tirana Airport       weather   19 Jan 2020, 10:20  11 km/h
# 7                 Bellambi Aws       weather   19 Jan 2020, 19:00   6 km/h
# 8                      Landeck       weather   19 Jan 2020, 10:00   7 km/h
# 9                         Retz       weather   19 Jan 2020, 10:00   7 km/h
#
#           forecast feels_like index_date_format
# index
# 0        13 / 2 °C      10 °C        2020.01.19
# 1       16 / 13 °C      16 °C        2020.01.19
# 2       25 / 18 °C      21 °C        2020.01.19
# 3       30 / 26 °C      36 °C        2020.01.19
# 4        0 / -9 °C      -2 °C        2020.01.19
# 5        1 / -3 °C       0 °C        2020.01.19
# 6        14 / 2 °C      11 °C        2020.01.19
# 7       25 / 20 °C      22 °C        2020.01.19
# 8      -2 / -10 °C      -7 °C        2020.01.19
# 9        3 / -2 °C       0 °C        2020.01.19

# %%
df.info()
df.describe()
df.isna().sum()
df = df.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4748 entries, 0 to 4875
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   current_time       4748 non-null   object
#  1   crawled_at         4748 non-null   object
#  2   pressure           4748 non-null   object
#  3   country            4748 non-null   object
#  4   wind_direction     4748 non-null   object
#  5   sky                4748 non-null   object
#  6   uniq_id            4748 non-null   object
#  7   visibility         4748 non-null   object
#  8   temperature        4748 non-null   object
#  9   dev_point          4748 non-null   object
#  10  place              4748 non-null   object
#  11  location           4748 non-null   object
#  12  data_category      4748 non-null   object
#  13  latest_report      4748 non-null   object
#  14  wind               4748 non-null   object
#  15  forecast           4748 non-null   object
#  16  feels_like         4748 non-null   object
#  17  index_date_format  4748 non-null   object
# dtypes: object(18)
# memory usage: 704.8+ KB
#                  current_time                crawled_at pressure country  \
# count                    4748                      4748     4748    4748
# unique                    981                       362      109     181
# top     19 Jan 2020, 11:09:54  Sun Jan 19 15:39:56 2020      N/A     USA
# freq                       21                        23      216    1004
#
#          wind_direction              sky  \
# count              4748             4748
# unique                9              103
# top      from Northwest  Passing clouds.
# freq                965              650
#
#                                      uniq_id visibility temperature dev_point  \
# count                                   4748       4748        4748      4748
# unique                                  4748         41          79        77
# top     6817a79c-0213-5c79-bb75-88bc16ca44dd        N/A          2       2 °C
# freq                                       1       1613         376       396
#
#                                    place            location data_category  \
# count                               4748                4748          4748
# unique                              4748                2870             1
# top      Weather in Gjirokastër, Albania  Dortmund / Wickede       weather
# freq                                   1                  36          4748
#
#               latest_report     wind   forecast feels_like index_date_format
# count                  4748     4748       4748       4748              4748
# unique                  258       39        792         95                 1
# top      19 Jan 2020, 10:20  7 km/h   4 / -1 °C       0 °C        2020.01.19
# freq                    557      574         82        442              4748
# current_time         0
# crawled_at           0
# pressure             0
# country              0
# wind_direction       0
# sky                  0
# uniq_id              0
# visibility           0
# temperature          0
# dev_point            0
# place                0
# location             0
# data_category        0
# latest_report        0
# wind                 0
# forecast             0
# feels_like           0
# index_date_format    0
# dtype: int64

# %%
df = df.rename(columns={'temparature': 'temperature'})
df.info()
# df['temperature'] = df['temperature'].str.strip('°C')
# df['pressure'] = df['pressure'].str.strip('mbar')
# df['pressure'] = df['pressure'].str.strip()
df['pressure'] = df['pressure'].astype(int)
df['dev_point'] = df['dev_point'].str.replace('°C', '', regex=False)
# df['feels_like'] = df['feels_like'].str.replace('°C', '', regex=False)
df = df[df['pressure'] != 'N/A']
df['visibility'] = df['visibility'].str.replace('N/A', '0', regex=False)
df['dev_point'] = df['dev_point'].str.replace('N/A', '0', regex=False)
df['visibility'] = df['visibility'].str.replace('km', '', regex=False)
df['visibility'] = df['visibility'].str.strip('\xa0')
df['dev_point'] = df['dev_point'].str.strip('\xa0')
# df['feels_like'] = df['feels_like'].str.strip('\xa0')
df['feels_like'] = df['feels_like'].astype(int)
df['dev_point'] = df['dev_point'].astype(int)
df['visibility'] = df['visibility'].astype(int)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4532 entries, 0 to 4874
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   current_time       4532 non-null   object
#  1   crawled_at         4532 non-null   object
#  2   pressure           4532 non-null   int64
#  3   country            4532 non-null   object
#  4   wind_direction     4532 non-null   object
#  5   sky                4532 non-null   object
#  6   uniq_id            4532 non-null   object
#  7   visibility         4532 non-null   object
#  8   temperature        4532 non-null   int64
#  9   dev_point          4532 non-null   object
#  10  place              4532 non-null   object
#  11  location           4532 non-null   object
#  12  data_category      4532 non-null   object
#  13  latest_report      4532 non-null   object
#  14  wind               4532 non-null   object
#  15  forecast           4532 non-null   object
#  16  feels_like         4532 non-null   int64
#  17  index_date_format  4532 non-null   object
# dtypes: int64(3), object(15)
# memory usage: 672.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 4532 entries, 0 to 4874
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   current_time       4532 non-null   object
#  1   crawled_at         4532 non-null   object
#  2   pressure           4532 non-null   int64
#  3   country            4532 non-null   object
#  4   wind_direction     4532 non-null   object
#  5   sky                4532 non-null   object
#  6   uniq_id            4532 non-null   object
#  7   visibility         4532 non-null   int64
#  8   temperature        4532 non-null   int64
#  9   dev_point          4532 non-null   int64
#  10  place              4532 non-null   object
#  11  location           4532 non-null   object
#  12  data_category      4532 non-null   object
#  13  latest_report      4532 non-null   object
#  14  wind               4532 non-null   object
#  15  forecast           4532 non-null   object
#  16  feels_like         4532 non-null   int64
#  17  index_date_format  4532 non-null   object
# dtypes: int64(5), object(13)
# memory usage: 672.7+ KB
#                 current_time                crawled_at  pressure  \
# index
# 0      19 Jan 2020, 11:06:34  Sun Jan 19 15:36:34 2020      1020
# 1      19 Jan 2020, 20:36:34  Sun Jan 19 15:36:34 2020      1008
# 2      19 Jan 2020, 21:06:34  Sun Jan 19 15:36:34 2020      1006
# 3      19 Jan 2020, 11:06:34  Sun Jan 19 15:36:34 2020      1012
# 5      19 Jan 2020, 11:06:34  Sun Jan 19 15:36:35 2020      1031
# ...                      ...                       ...       ...
# 4870   19 Jan 2020, 13:14:29  Sun Jan 19 15:44:29 2020      1018
# 4871   19 Jan 2020, 13:14:29  Sun Jan 19 15:44:29 2020      1018
# 4872   19 Jan 2020, 13:14:29  Sun Jan 19 15:44:29 2020      1019
# 4873   19 Jan 2020, 13:14:29  Sun Jan 19 15:44:29 2020      1021
# 4874   19 Jan 2020, 11:14:29  Sun Jan 19 15:44:30 2020      1026
#
#             country   wind_direction                sky  \
# index
# 0           Albania   from Southeast     Broken clouds.
# 1         Australia       from South              Cool.
# 2         Australia               na              Mild.
# 3            Angola   from Southwest  Scattered clouds.
# 5           Austria   from Northwest            Chilly.
# ...             ...              ...                ...
# 4870   Saudi Arabia       from North             Clear.
# 4871   Saudi Arabia        from West  Scattered clouds.
# 4872   Saudi Arabia   from Northwest    Passing clouds.
# 4873   Saudi Arabia        from West             Sunny.
# 4874     San Marino        from West               Fog.
#
#                                     uniq_id  visibility  temperature  \
# index
# 0      6817a79c-0213-5c79-bb75-88bc16ca44dd           0           11
# 1      215d740f-ed79-5643-80a3-5fdcbc7b6b54           0           16
# 2      fe46e09e-8735-54bd-9e86-19ae8335e915           0           22
# 3      6aa0c99b-30b6-5e10-bddc-523b24ca8f63           0           30
# 5      902c57ff-f415-5a3a-9566-7979c4a9b8f9           0            2
# ...                                     ...         ...          ...
# 4870   87ca623c-89d5-562a-b9f3-123fc2ecc7d8           8           19
# 4871   b84eef51-efec-5620-9e7e-b77d0d57e1e6           0           12
# 4872   7aaa38ec-a477-5cb0-b6e8-4538a1f6cd38           0           24
# 4873   ac18ce15-8bb1-582f-9592-73e9159acc61          16           18
# 4874   55d1aa96-f184-5b4f-a75d-cbf2e8982060           5            7
#
#        dev_point                                              place  \
# index
# 0              8                    Weather in Gjirokastër, Albania
# 1             15   Weather in Mount Gambier, South Australia, Au...
# 2             19        Weather in Eden, New South Wales, Australia
# 3             25                         Weather in Cabinda, Angola
# 5              1          Weather in Zwettl, Lower Austria, Austria
# ...          ...                                                ...
# 4870           6                    Weather in Riyadh, Saudi Arabia
# 4871           6                    Weather in Turaif, Saudi Arabia
# 4872          11                    Weather in Jeddah, Saudi Arabia
# 4873           6                    Weather in Medina, Saudi Arabia
# 4874           6                  Weather in San Marino, San Marino
#
#                                            location data_category  \
# index
# 0                                   Kerkyra Airport       weather
# 1                           Mount Gambier Aerodrome       weather
# 2                                    Green Cape Aws       weather
# 3                              Pointe Airport-Noire       weather
# 5                                              Retz       weather
# ...                                             ...           ...
# 4870                                 Riyadh Airport       weather
# 4871                                         Turaif       weather
# 4872   Jeddah King Abdul Aziz International Airport       weather
# 4873                                        Madinah       weather
# 4874                                 Rimini Airport       weather
#
#              latest_report      wind    forecast  feels_like index_date_format
# index
# 0       19 Jan 2020, 10:20  11 km/h    13 / 2 °C          10        2020.01.19
# 1       19 Jan 2020, 19:30  30 km/h   16 / 13 °C          16        2020.01.19
# 2       19 Jan 2020, 20:00   No wind  25 / 18 °C          21        2020.01.19
# 3       19 Jan 2020, 10:00   7 km/h   30 / 26 °C          36        2020.01.19
# 5       19 Jan 2020, 10:00   7 km/h    1 / -3 °C           0        2020.01.19
# ...                    ...       ...         ...         ...               ...
# 4870    19 Jan 2020, 12:00  15 km/h   21 / 13 °C          19        2020.01.19
# 4871    19 Jan 2020, 12:00  19 km/h    12 / 3 °C          10        2020.01.19
# 4872    19 Jan 2020, 12:00  15 km/h   26 / 18 °C          25        2020.01.19
# 4873    19 Jan 2020, 12:00  11 km/h    22 / 9 °C          18        2020.01.19
# 4874    19 Jan 2020, 10:20  13 km/h    0 / -2 °C           5        2020.01.19
#
# [4532 rows x 18 columns]

# %%
df['feels_like'].unique()
# Out:
# array([ 10,  16,  21,  36,   0,  11,  -7,  24,   7,   2,  27,  28,   1,
#         -1,   5,   3,  -2,  -3,  -5,  -4,  25,  32,  31,  23,   8,  14,
#         13,  12,   9,  26,  18,  19,  15,  20,  35,  33,  30,  41,  37,
#         17,  29,  40,  38,  22, -11,   6,  34,  44,  43,   4, -17,  39,
#         -6,  42, -10, -13, -14, -21, -35, -25,  -8, -43,  -9, -19, -36,
#        -39, -15, -23, -26, -33, -28, -12, -31, -20, -47, -37, -24, -42,
#        -27, -22, -34, -29, -18, -44, -16, -40, -46, -49, -32, -30, -41,
#        -38, -48, -51, -45])

# %%
df.head(10)
# Out:
#                 current_time                crawled_at  pressure    country  \
# index
# 0      19 Jan 2020, 11:06:34  Sun Jan 19 15:36:34 2020      1020    Albania
# 1      19 Jan 2020, 20:36:34  Sun Jan 19 15:36:34 2020      1008  Australia
# 2      19 Jan 2020, 21:06:34  Sun Jan 19 15:36:34 2020      1006  Australia
# 3      19 Jan 2020, 11:06:34  Sun Jan 19 15:36:34 2020      1012     Angola
# 5      19 Jan 2020, 11:06:34  Sun Jan 19 15:36:35 2020      1031    Austria
# 6      19 Jan 2020, 11:06:34  Sun Jan 19 15:36:35 2020      1021    Albania
# 8      19 Jan 2020, 11:06:35  Sun Jan 19 15:36:35 2020      1036    Austria
# 9      19 Jan 2020, 11:06:35  Sun Jan 19 15:36:35 2020      1031    Austria
# 10     19 Jan 2020, 11:06:35  Sun Jan 19 15:36:35 2020      1014      Benin
# 11     19 Jan 2020, 11:06:35  Sun Jan 19 15:36:35 2020      1018      Benin
#
#         wind_direction                sky  \
# index
# 0       from Southeast     Broken clouds.
# 1           from South              Cool.
# 2                   na              Mild.
# 3       from Southwest  Scattered clouds.
# 5       from Northwest            Chilly.
# 6           from South  Scattered clouds.
# 8       from Southeast            Chilly.
# 9       from Northwest            Chilly.
# 10      from Northeast      Partly sunny.
# 11           from East              Haze.
#
#                                     uniq_id  visibility  temperature  \
# index
# 0      6817a79c-0213-5c79-bb75-88bc16ca44dd           0           11
# 1      215d740f-ed79-5643-80a3-5fdcbc7b6b54           0           16
# 2      fe46e09e-8735-54bd-9e86-19ae8335e915           0           22
# 3      6aa0c99b-30b6-5e10-bddc-523b24ca8f63           0           30
# 5      902c57ff-f415-5a3a-9566-7979c4a9b8f9           0            2
# 6      31612738-627f-5dbb-a7e7-b2bc4e86fdd8           0           12
# 8      eb0c5057-19df-5b83-9850-e7bf3760d2bc           0           -4
# 9      cc5457af-5518-5bc9-bbdc-2b7a4049263c           0            2
# 10     45edb7bb-0959-5acb-93e0-539d1d4c69f8           1           22
# 11     465c11d0-659b-58a9-8df6-46aa72e23112           2           22
#
#        dev_point                                              place  \
# index
# 0              8                    Weather in Gjirokastër, Albania
# 1             15   Weather in Mount Gambier, South Australia, Au...
# 2             19        Weather in Eden, New South Wales, Australia
# 3             25                         Weather in Cabinda, Angola
# 5              1          Weather in Zwettl, Lower Austria, Austria
# 6              6                         Weather in Tirana, Albania
# 8             -7                  Weather in Reutte, Tyrol, Austria
# 9              1      Weather in Hollabrunn, Lower Austria, Austria
# 10             2                          Weather in Parakou, Benin
# 11            -1                          Weather in Djougou, Benin
#
#                       location data_category        latest_report      wind  \
# index
# 0              Kerkyra Airport       weather   19 Jan 2020, 10:20  11 km/h
# 1      Mount Gambier Aerodrome       weather   19 Jan 2020, 19:30  30 km/h
# 2               Green Cape Aws       weather   19 Jan 2020, 20:00   No wind
# 3         Pointe Airport-Noire       weather   19 Jan 2020, 10:00   7 km/h
# 5                         Retz       weather   19 Jan 2020, 10:00   7 km/h
# 6               Tirana Airport       weather   19 Jan 2020, 10:20  11 km/h
# 8                      Landeck       weather   19 Jan 2020, 10:00   7 km/h
# 9                         Retz       weather   19 Jan 2020, 10:00   7 km/h
# 10                     Parakou       weather   19 Jan 2020, 10:00  32 km/h
# 11                  Niamtougou       weather   19 Jan 2020, 10:00  28 km/h
#
#           forecast  feels_like index_date_format
# index
# 0        13 / 2 °C          10        2020.01.19
# 1       16 / 13 °C          16        2020.01.19
# 2       25 / 18 °C          21        2020.01.19
# 3       30 / 26 °C          36        2020.01.19
# 5        1 / -3 °C           0        2020.01.19
# 6        14 / 2 °C          11        2020.01.19
# 8      -2 / -10 °C          -7        2020.01.19
# 9        3 / -2 °C           0        2020.01.19
# 10      36 / 16 °C          24        2020.01.19
# 11      35 / 15 °C          24        2020.01.19

# %%
g = sns.relplot(x='current_time', y='temperature', data=df, kind='line')
g.set(xlabel='Time', ylabel='Temperature')
g.fig.suptitle('Temperature from 1/19 to 1/20', y=1.03 )
plt.xticks(rotation=68)
plt.show()
# Out:
# Text(0.5, 1.03, 'Temperature from 1/19 to 1/20')
# (array([18280.   , 18280.125, 18280.25 , 18280.375, 18280.5  , 18280.625,
#         18280.75 , 18280.875, 18281.   ]),
#  [Text(18280.0, 0, '01-19 00'),
#   Text(18280.125, 0, '01-19 03'),
#   Text(18280.25, 0, '01-19 06'),
#   Text(18280.375, 0, '01-19 09'),
#   Text(18280.5, 0, '01-19 12'),
#   Text(18280.625, 0, '01-19 15'),
#   Text(18280.75, 0, '01-19 18'),
#   Text(18280.875, 0, '01-19 21'),
#   Text(18281.0, 0, '01-20 00')])

# %%
dfNorthAmerica = df[df['country'].isin(['USA', "Mexico", 'Canada'])]
df.pivot_table(values = 'temperature', index = 'country', columns = 'wind_direction')
# Out:
# wind_direction   from East   from North   from Northeast   from Northwest  \
# country
# Afghanistan       4.000000          NaN              NaN              NaN
# Albania                NaN          NaN             10.0              1.0
# Algeria           6.000000          NaN              8.0              8.0
# Andorra                NaN          NaN              NaN              NaN
# Angola                 NaN          NaN              NaN              NaN
# ...                    ...          ...              ...              ...
# Vanuatu                NaN          NaN             25.0              NaN
# Venezuela        23.333333          NaN             19.5              NaN
# Vietnam          26.500000         24.5             21.5              NaN
# Württemberg            NaN          NaN              NaN              1.0
# Yemen                  NaN          NaN              NaN              NaN
#
# wind_direction   from South   from Southeast   from Southwest   from West  na
# country
# Afghanistan             NaN              NaN              NaN         8.0 NaN
# Albania                12.0              8.5              NaN         NaN NaN
# Algeria                11.0              9.0             11.0        14.0 NaN
# Andorra                 NaN              NaN              NaN         6.0 NaN
# Angola                  NaN              NaN             30.0         NaN NaN
# ...                     ...              ...              ...         ...  ..
# Vanuatu                27.0              NaN              NaN         NaN NaN
# Venezuela               NaN             26.0              NaN         NaN NaN
# Vietnam                 NaN             26.0              NaN         NaN NaN
# Württemberg             NaN              NaN              NaN         NaN NaN
# Yemen                   NaN              NaN             24.0         NaN NaN
#
# [179 rows x 9 columns]
